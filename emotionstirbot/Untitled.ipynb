# %%
import os
from dotenv import load_dotenv

load_dotenv()

gemini_key = os.getenv('GEMINI_API_KEY')
print(gemini_key)
# Out:
# AIzaSyAsYvc019Cg0a3fxlP7kfbQvS0v-2bLC0Q

# %%
from google import genai
from google.genai import types
config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    )

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words",
    config=config
)
print(response.text)
# Out:
# AI works by finding patterns in data.

# %%
with open("sys_instruc.txt") as f:
    sys_instruc=f.read()
config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=5000),
        system_instruction=sys_instruc
    )
chat = client.chats.create(model="gemini-2.5-flash", config=config)

# %%
inp=""
while not inp.startswith("END"):
    inp=input()
    response = chat.send_message(inp)
    print(response.text)

# %%
contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""Hello, I am like ... umm... so gayy hehehehehe"""),
            ],
        ),
    ]
generate_content_config = types.GenerateContentConfig(
    temperature=1.3,
    response_modalities=[
        "audio",
    ],
    speech_config=types.SpeechConfig(
        voice_config=types.VoiceConfig(
            prebuilt_voice_config=types.PrebuiltVoiceConfig(
                voice_name="Umbriel"
            )
        )
    ),
)
response = client.models.generate_content(
  model="gemini-2.5-flash-preview-tts",
  contents=contents,
  config=generate_content_config
)
response.candidates[0].content.parts[0].inline_data
# Out:
# Blob(
#   data=b'\xd6\xff\xcd\xff\xce\xff\xd7\xff\xdb\xff\xdb\xff\xe5\xff\xfd\xff\x0e\x00\x0c\x00\x13\x00\x05\x00\xe7\xff\xd3\xff\xdc\xff\xf9\xff\x02\x00\x07\x00\x06\x00\xe7\xff\xd4\xff\xe3\xff\x06\x00)\x00\\\x00\x88\x00\x86\x00c\x00D\x00!\x00\xec\xff\xd9\xff\xdd\xff\xe0\xff\xff\xff/\x00L\x004\x001\x00"\x00\xf0\xff\xd3\xff\xc4\xff\xc7\xff\xbf\xff\xc9\xff\xd4\xff\xde\xff\xdd...',
#   mime_type='audio/L16;codec=pcm;rate=24000'
# )

# %%
import base64

# %%
byte_data = response.candidates[0].content.parts[0].inline_data
# base64.b64encode(byte_data).decode("utf-8")
byte_data
# Out:
# Blob(
#   data=b'\xf6\xff\xf6\xff\xfb\xff\xf5\xff\xfa\xff\t\x00\x13\x00\x18\x00\x10\x00\xfd\xff\xeb\xff\xd8\xff\xce\xff\xd4\xff\xe2\xff\xf1\xff\xf7\xff\xf2\xff\xf3\xff\xe2\xff\xcc\xff\xc6\xff\xc8\xff\xce\xff\xd8\xff\xdf\xff\xe5\xff\xe9\xff\xe4\xff\xe3\xff\xe6\xff\xe7\xff\xeb\xff\xfd\xff\t\x00\x16\x00\x1e\x00\t\x00\xed\xff\xcc\xff\xb3\xff\xa1\xff\xaf\xff\xc8\xff\xe9\xff\x0c\x00+\x00<\x009...',
#   mime_type='audio/L16;codec=pcm;rate=24000'
# )

# %%
b''

# %%
# Original byte array
byte_array = b'This is some binary data.'

# Encode the byte array to Base64 bytes
base64_bytes = base64.b64encode(byte_data)

# Decode the Base64 bytes to a string
base64_string = base64_bytes.decode('utf-8')

print(f"Original byte array: {byte_data}")
print(f"Base64 encoded string: {base64_string}")
# Out:
# Original byte array: b'\xf6\xff\xf6\xff\xfb\xff\xf5\xff\xfa\xff\t\x00\x13\x00\x18\x00\x10\x00\xfd\xff\xeb\xff\xd8\xff\xce\xff\xd4\xff\xe2\xff\xf1\xff\xf7\xff\xf2\xff\xf3\xff\xe2\xff\xcc\xff\xc6\xff\xc8\xff\xce\xff\xd8\xff\xdf\xff\xe5\xff\xe9\xff\xe4\xff\xe3\xff\xe6\xff\xe7\xff\xeb\xff\xfd\xff\t\x00\x16\x00\x1e\x00\t\x00\xed\xff\xcc\xff\xb3\xff\xa1\xff\xaf\xff\xc8\xff\xe9\xff\x0c\x00+\x00<\x009\x00(\x00\x1f\x00\x1e\x00\x17\x00\x14\x00\x17\x00\x17\x00\x1c\x00 \x00!\x00"\x00!\x00,\x00\'\x00\x1d\x00\r\x00\xf8\xff\xe0\xff\xe0\xff\xeb\xff\xfe\xff\x15\x00%\x00.\x00 \x00\x11\x00\xfe\xff\xf3\xff\xeb\xff\xe9\xff\xf6\xff\xfc\xff\xfe\xff\x0b\x00\x15\x00\x1f\x00+\x002\x00*\x00\x1e\x00\x19\x00\x14\x00\x01\x00\xe3\xff\xcd\xff\xbc\xff\xae\xff\xc0\xff\xe5\xff\x05\x00\x17\x00#\x00"\x00\x19\x00\x0e\x00\x05\x00\xf6\xff\xec\xff\xe8\xff\xf1\xff\x07\x00\x0e\x00\x14\x00\x1f\x00&\x00-\x00-\x00-\x00)\x00\x1e\x00\x15\x00\x10\x00\x08\x00\x00\x00\xff\xff\x00\x00\xfd\xff\x05\x00\x12\x00\x14\x00\x0c\x00\xf9\xff\xe
# ...
