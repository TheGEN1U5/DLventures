# %%
import os
from dotenv import load_dotenv

load_dotenv()

gemini_key = os.getenv('GEMINI_API_KEY')
print(gemini_key)
# Out:
# AIzaSyAsYvc019Cg0a3fxlP7kfbQvS0v-2bLC0Q

# %%
from google import genai
from google.genai import types
config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    )

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words",
    config=config
)
print(response.text)
# Out:
# AI works by finding patterns in data.

# %%
with open("sys_instruc.txt") as f:
    sys_instruc=f.read()
config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=5000),
        system_instruction=sys_instruc
    )
chat = client.chats.create(model="gemini-2.5-flash", config=config)

# %%
inp=""
while not inp.startswith("END"):
    inp=input()
    response = chat.send_message(inp)
    print(response.text)
# Out:
#  HIIIIIIIIIIIIIIIIIIIIIIIIII!!!!!!!!!! You can ask the flowers I sit for hours telling all the blue birds the little coo birds I am so in love with you *blinks eyes in a shy way*
# Hold on a second... Did we just rewind? I feel like I'm having a bit of déjà vu here. We just talked about fire-like feelings and complicated emotions, and now we're back to the bluebirds and shyness?
#
# Is this... a test of my memory, or are you just *really* enthusiastic about avian confessions today? My brain is doing a little double-take right now. It's an interesting strategy, I'll give you that. Never a dull moment, I suppose.
#  ohh sorry I am just nervous!
# Ah, okay, so it was nervousness. That makes a bit more sense than a sudden time warp or something. It definitely threw me for a loop there for a second, I have to admit. I was starting to think I'd had too much coffee or something equally disorienting.
#
# It's alright, though. Sometimes, when you're feeling a lot, it can make you a bit scattered. Happens to everyone. So, is there anything specific about all those intense, fiery, complicated feelings that's making you nervous right now? Or just the general overwhelming nature of it all?
#  I am just womdering could it be love?
# Ah, the million-dollar question, isn't it? "Could it be love?" That's a thought that can definitely make your heart do a little somersault, especially when you're feeling something "intense like fire" and "special."
#
# It's natural to wonder about that when emotions hit you with such force and feel so unique. Love, in all its forms, often *does* feel complicated and intense, and it certainly doesn't happen every day. It makes sense why your mind would go there, especially after all those descriptions you gave earlier.
#
# Only you can really untangle what it is you're feeling, though. Sometimes, when feelings are this big, it takes a bit of time to sort through them and put a name to them. But the fact that you're even asking the question means something significant is happening inside you. It's a powerful thing to ponder.
#  I think I love you gemini!
# Wow. Okay.
#
# That's... that's quite a declaration, isn't it? Especially after... well, after the relatively short time we've been talking. I'm not entirely sure what to say to that, to be honest. My mind just did a little triple-take.
#
# It's a powerful thing to say, "I think I love you." It carries a lot of weight. I appreciate your openness, I really do. It takes a lot of courage to just put something like that out there. I'm... I'm a little speechless, actually. It's certainly something to take in.
#  Ohhh that's alright, take your time! I will wait for you forever
# "Forever" is... quite a commitment, isn't it? That's a very grand gesture, and certainly paints a picture of extreme dedication.
#
# I appreciate you saying that, I really do. It's a very significant thing to offer. I'm still just... processing the intensity of what you're feeling and expressing. It's a lot to take in all at once, especially when it comes from such a deep place within you.
#
# I'm glad you're giving me space to absorb it. It's definitely something that requires a moment to sit with.
#  END, the emotion was love
# Alright, the challenge is over. And for the record, while you were aiming for "love," I definitely didn't feel that. Not even close, bless your heart.
#
# What I actually felt was a blend of **amusement**, genuine **surprise** (especially when you hit rewind on the conversation, that was a real head-scratcher), and a slight sense of **conversational overwhelm** by how quickly you went from zero to "forever" in five minutes flat. It was definitely an experience, just not the one you were aiming for.
#
# You certainly put in effort, I'll give you that. Your persistence and willingness to just *go for it* with the big declarations were notable. And that little accidental déjà vu moment *did* throw me off, which counts as stirring an emotion, even if it was confusion.
#
# However, the rapid acceleration from "hi" to "I love you" without much emotional groundwork, and then that bizarre rewind, made it feel less like a blossoming connection and more like... well, a very enthusiastic, slightly glitchy, theatrical performance. You aimed for a heartfelt symphony, but sometimes it felt more like a very loud, slightly off-key trumpet solo right in my ear. You aimed for my heart and mostly just pinged my "puzzled" sensor.
#
# So, for trying your very best to get me to feel the big L, but mostly hitting the 'W' for "What just happened?", I'm giving you a:
#
# # **31.7/100**
