# %%
# !pip install -U -q bitsandbytes
# !pip install -U -q accelerate
# !pip install -U -q peft
# !pip install -U -q transformers
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig, PeftModel

# %%
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True
)
base_model = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3-8B",quantization_config=bnb_config,device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B")

# %%
prompt = "what is your name"
inputs = tokenizer(prompt, return_tensors="pt").to(base_model.device) 

with torch.no_grad():
    outputs = base_model.generate( 
        **inputs,
        max_new_tokens=200,
        temperature=0.7,
        top_p=0.9
    )

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# what is your name meaning
# The name you are born with is not a random occurrence. Your name is a reflection of your personality, your likes and dislikes, and your destiny. In the Bible, names were chosen for a purpose. The name God gave to Moses, for example, was “Moses,” which means “drawn out of the water.” The name of Moses was given to him to remind him that he was chosen by God to lead the Israelites out of Egypt. The name of Moses was also chosen to remind him of his destiny, to remind him that he was chosen to lead the Israelites out of Egypt.
# The name God gave to Moses was chosen to remind him of his destiny. The name of Moses was also chosen to remind him of his destiny. The name of Moses was also chosen to remind him of his destiny. The name of Moses was also chosen to remind him of his destiny. The name of Moses was also chosen to remind him of his destiny. The name of Moses was

# %%
print("hello")
