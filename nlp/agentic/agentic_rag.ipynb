# %%
# !pip install -q langchain-groq langgraph
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.7/216.7 kB 12.9 MB/s eta 0:00:00

# %%
from google.colab import userdata
import os
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
os.environ["LANGSMITH_API_KEY"] = userdata.get("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING_V2"] = "true"
os.environ["LANGSMITH_PROJECT"] = "agentic-rag"

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="qwen/qwen3-32b")

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# %%
class OrchestratorState(TypedDict):
    query: str
    query_graph: dict
    docs: list
    docs_heirarchy: list
    reasoning: str
    relevant_docs: list
    answer: str

# %%
class ReasoningWorkerState(TypedDict):
    query: str
    query_graph: dict
    docs_heirarchy: list

REASONING_WORKER_SYSTEM_MESSAGE = SystemMessage(
    content="""
# Out:
#   File "/tmp/ipython-input-915363012.py", line 6
#     content="""
#             ^
# SyntaxError: incomplete input

# %%
builder = StateGraph(ReasoningWorkerState)
builder.add_edge(START, END)

orchestrator = builder.compile()

# %%
# Out:
# AIMessage(content='<think>\nOkay, the user wrote "hello". That\'s a greeting. I should respond in a friendly and welcoming manner. Let me make sure to acknowledge their greeting and offer assistance. Maybe say something like "Hello! How can I assist you today?" to keep the conversation open. Keep it simple and approachable.\n</think>\n\nHello! How can I assist you today? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 9, 'total_tokens': 87, 'completion_time': 0.139684574, 'prompt_time': 0.006979011, 'queue_time': 0.052134899, 'total_time': 0.146663585}, 'model_name': 'qwen/qwen3-32b', 'system_fingerprint': 'fp_5cf921caa2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--86523840-ec98-4959-8c4b-4f05da4bbb66-0', usage_metadata={'input_tokens': 9, 'output_tokens': 78, 'total_tokens': 87})

# %%
orchestrator.invoke({"query": "why?"})
# Out:
# {'query': 'why?'}

# %%
class VectorStoreBuilderState(TypedDict):
    query: str
    docs_heirarchy: list
